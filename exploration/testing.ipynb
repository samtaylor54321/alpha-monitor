# %%
from alpha_monitor.data.data_scrapper import YahooFinanceDataSource

data = YahooFinanceDataSource()

rheinmetall = data.get_prices("RHM.DE")


print(rheinmetall.attrs["currency"])
print(rheinmetall.tail(20))
# Out:
# EUR
#                              open    high     low   close  Adj Close  volume  \
# date
# 2026-01-12 00:00:00+01:00  1912.0  1935.5  1873.5  1890.0     1890.0  228271
# 2026-01-13 00:00:00+01:00  1888.5  1905.0  1879.5  1904.0     1904.0  171188
# 2026-01-14 00:00:00+01:00  1904.0  1907.5  1853.0  1899.0     1899.0  186138
# 2026-01-15 00:00:00+01:00  1886.0  1920.0  1872.5  1913.5     1913.5  219265
# 2026-01-16 00:00:00+01:00  1914.5  1935.0  1900.5  1902.0     1902.0  196525
# 2026-01-19 00:00:00+01:00  1937.0  1966.0  1918.5  1920.0     1920.0  287594
# 2026-01-20 00:00:00+01:00  1923.0  1928.5  1871.5  1909.0     1909.0  203121
# 2026-01-21 00:00:00+01:00  1904.5  1917.0  1836.5  1853.5     1853.5  247607
# 2026-01-22 00:00:00+01:00  1797.0  1822.0  1759.0  1790.5     1790.5  348717
# 2026-01-23 00:00:00+01:00  1750.0  1844.0  1750.0  1830.0     1830.0  260828
# 2026-01-26 00:00:00+01:00  1856.0  1859.5  1777.5  1791.0     1791.0  171471
# ...
